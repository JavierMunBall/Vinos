# %%
pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 35.2 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=cc53f1a8a150c60a1fe03e35294562b615138776bf2cd2198b789929f0888822
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 docker-pycreds-0.4.0 gitdb-4.0.11 pathtools-0.1.2 sentry-sdk-1.34.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.15.12

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
import wandb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np

# %%
wine = load_wine()

# %%
X, y = wine.data, wine.target

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3, random_state=357) #cambiar tamaño de test para ver como se comporta

# %%
hyperparameters = {
    'learning_rates': [0.01, 0.1, 0.2, 0.25],
    'max_depths': [2, 3, 4, 5],
    'n_estimators': [50, 100, 150],
    'loss_functions': ['deviance'],  # otras son log_loss, squared_error
    'subsamples': [0.8, 1.0],  # una tasa mas baja previene el sobreajuste pero influye en la varianza del modelo
    'min_samples_splits': [2, 4],
    'min_samples_leafs': [1, 2]
}

for lr in hyperparameters['learning_rates']:
    for max_depth in hyperparameters['max_depths']:
        for n_estimator in hyperparameters['n_estimators']:
            for loss_function in hyperparameters['loss_functions']:
                for subsample in hyperparameters['subsamples']:
                    for min_samples_split in hyperparameters['min_samples_splits']:
                        for min_samples_leaf in hyperparameters['min_samples_leafs']:
                            experiment_name = f"gbm_lr{lr}_depth{max_depth}_est{n_estimator}_loss{loss_function}_subsample{subsample}_minsplit{min_samples_split}_minleaf{min_samples_leaf}"
                            wandb.init(project="vinito-upgrade", name=experiment_name, config=hyperparameters)

                            clf = GradientBoostingClassifier(learning_rate=lr, max_depth=max_depth, n_estimators=n_estimator,
                                                             loss=loss_function, subsample=subsample, min_samples_split=min_samples_split,
                                                             min_samples_leaf=min_samples_leaf, random_state=357, validation_fraction=0.1,
                                                             n_iter_no_change=5, tol=0.01)

                            clf.fit(X_train, y_train)

                            # Make predictions
                            y_pred = clf.predict(X_test)
                            y_pred_proba = clf.predict_proba(X_test)

                            # Log hyperparameters to wandb
                            wandb.config.learning_rate = lr
                            wandb.config.max_depth = max_depth
                            wandb.config.n_estimators = n_estimator
                            wandb.config.loss_function = loss_function
                            wandb.config.subsample = subsample
                            wandb.config.min_samples_split = min_samples_split
                            wandb.config.min_samples_leaf = min_samples_leaf

                            # Calculate performance metrics
                            accuracy = accuracy_score(y_test, y_pred)
                            f1_macro = f1_score(y_test, y_pred, average="macro")
                            y_test_bin = label_binarize(y_test, classes=np.unique(y))
                            y_pred_bin = y_pred_proba.reshape(-1, len(np.unique(y)))
                            roc_auc_macro = roc_auc_score(y_test_bin, y_pred_bin, average="macro", multi_class="ovr")

                            # Log metrics to wandb
                            wandb.log({"accuracy": accuracy, "f1_macro": f1_macro, "roc_auc_macro": roc_auc_macro,
                                       "validation_score": clf.train_score_[-1]})

                            # Finish the experiment
                            wandb.finish()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110819-it89b6q6</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/it89b6q6' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/it89b6q6' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/it89b6q6</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.51842</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/it89b6q6' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/it89b6q6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110819-it89b6q6/logs</code>
# wandb: Currently logged in as: javier-munoz. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110827-rxyrdbr9</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rxyrdbr9' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rxyrdbr9' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/rxyrdbr9</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.52217</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rxyrdbr9' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/rxyrdbr9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110827-rxyrdbr9/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110833-dt5fbacq</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/dt5fbacq' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/dt5fbacq' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/dt5fbacq</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.51842</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/dt5fbacq' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/dt5fbacq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110833-dt5fbacq/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110839-rtjsfc1t</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rtjsfc1t' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rtjsfc1t' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/rtjsfc1t</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.52217</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample0.8_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/rtjsfc1t' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/rtjsfc1t</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110839-rtjsfc1t/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110845-xm5jbgpb</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/xm5jbgpb' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/xm5jbgpb' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/xm5jbgpb</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9301</td></tr><tr><td>roc_auc_macro</td><td>0.98581</td></tr><tr><td>validation_score</td><td>0.51212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/xm5jbgpb' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/xm5jbgpb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110845-xm5jbgpb/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110851-lomvohoo</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/lomvohoo' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/lomvohoo' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/lomvohoo</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9301</td></tr><tr><td>roc_auc_macro</td><td>0.98581</td></tr><tr><td>validation_score</td><td>0.51212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/lomvohoo' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/lomvohoo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110851-lomvohoo/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110857-9px5c07d</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/9px5c07d' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/9px5c07d' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/9px5c07d</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9301</td></tr><tr><td>roc_auc_macro</td><td>0.98581</td></tr><tr><td>validation_score</td><td>0.51212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/9px5c07d' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/9px5c07d</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110857-9px5c07d/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110903-l7ls2lik</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/l7ls2lik' target="_blank">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/l7ls2lik' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/l7ls2lik</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9301</td></tr><tr><td>roc_auc_macro</td><td>0.98581</td></tr><tr><td>validation_score</td><td>0.51212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est50_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/l7ls2lik' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/l7ls2lik</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110903-l7ls2lik/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_110909-zesvt50f</code>
# Syncing run <strong><a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/zesvt50f' target="_blank">gbm_lr0.01_depth2_est100_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/javier-munoz/vinito-upgrade' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade</a>
#  View run at <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/zesvt50f' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/zesvt50f</a>
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99554</td></tr><tr><td>validation_score</td><td>0.26645</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.01_depth2_est100_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/javier-munoz/vinito-upgrade/runs/zesvt50f' target="_blank">https://wandb.ai/javier-munoz/vinito-upgrade/runs/zesvt50f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231107_110909-zesvt50f/logs</code>
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/content/wandb/run-20231107_